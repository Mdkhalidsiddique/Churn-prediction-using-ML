# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\Md Khalid Siddique\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df1 = pd.read_csv('txn_data.csv')
df2 = pd.read_csv('ticket_data.csv')

# %%
df1.head()
# Out:
#    Amount  PayeeRefID              CreatedDate  TransactionStatusRefID  \
# 0     2.0       12104  2018-10-14 13:52:31 UTC                       2
# 1     2.0       12104  2018-08-11 16:55:33 UTC                       2
# 2     2.0    24979501  2019-02-21 16:33:03 UTC                       2
# 3     2.0       12104  2018-09-20 18:15:22 UTC                       2
# 4   100.0    15957319  2018-07-22 07:14:24 UTC                       2
#
#    CustID  DistributorRefID
# 0       1                 1
# 1       1                 1
# 2       1                 1
# 3       1                 1
# 4       1                 1

# %%
df2.head()
# Out:
#   TicketCreatedDateTime  CustID
# 0      12-11-2018 15:27       3
# 1      12-11-2018 15:29       3
# 2      19-09-2018 12:23       4
# 3      30-08-2018 12:18       4
# 4      14-09-2018 12:55       4

# %%
import timeit

# %%
df=pd.merge(df1, df2, how='outer', on='CustID',validate=None)

# %%
d=pd.merge(df1, df2, how='outer', left_on=df1['CustID'], right_on=df2['CustID'],
         left_index=False, right_index=False, sort=False,
         suffixes=('_x', '_y'), copy=True, indicator=False,
         validate=None)

# %%
d.head()
# Out:
#    key_0  Amount  PayeeRefID              CreatedDate  TransactionStatusRefID  \
# 0      1     2.0     12104.0  2018-10-14 13:52:31 UTC                     2.0
# 1      1     2.0     12104.0  2018-08-11 16:55:33 UTC                     2.0
# 2      1     2.0  24979501.0  2019-02-21 16:33:03 UTC                     2.0
# 3      1     2.0     12104.0  2018-09-20 18:15:22 UTC                     2.0
# 4      1   100.0  15957319.0  2018-07-22 07:14:24 UTC                     2.0
#
#    CustID_x  DistributorRefID TicketCreatedDateTime  CustID_y
# 0       1.0               1.0                   NaN       NaN
# 1       1.0               1.0                   NaN       NaN
# 2       1.0               1.0                   NaN       NaN
# 3       1.0               1.0                   NaN       NaN
# 4       1.0               1.0                   NaN       NaN

# %%
d.isnull().sum()
# Out:
# key_0                          0
# Amount                     24342
# PayeeRefID                 24342
# CreatedDate                24342
# TransactionStatusRefID     24342
# CustID_x                   24342
# DistributorRefID           24342
# TicketCreatedDateTime     394971
# CustID_y                  394971
# dtype: int64

# %%
result = pd.merge(df1, df2, how='outer', on='CustID')

# %%
result.head()
# Out:
#    Amount  PayeeRefID              CreatedDate  TransactionStatusRefID  \
# 0     2.0     12104.0  2018-10-14 13:52:31 UTC                     2.0
# 1     2.0     12104.0  2018-08-11 16:55:33 UTC                     2.0
# 2     2.0  24979501.0  2019-02-21 16:33:03 UTC                     2.0
# 3     2.0     12104.0  2018-09-20 18:15:22 UTC                     2.0
# 4   100.0  15957319.0  2018-07-22 07:14:24 UTC                     2.0
#
#    CustID  DistributorRefID TicketCreatedDateTime
# 0       1               1.0                   NaN
# 1       1               1.0                   NaN
# 2       1               1.0                   NaN
# 3       1               1.0                   NaN
# 4       1               1.0                   NaN

# %%
db = pd.concat([df1,df2], ignore_index = True)
db
# Out:
#          Amount  PayeeRefID              CreatedDate  TransactionStatusRefID  \
# 0           2.0     12104.0  2018-10-14 13:52:31 UTC                     2.0
# 1           2.0     12104.0  2018-08-11 16:55:33 UTC                     2.0
# 2           2.0  24979501.0  2019-02-21 16:33:03 UTC                     2.0
# 3           2.0     12104.0  2018-09-20 18:15:22 UTC                     2.0
# 4         100.0  15957319.0  2018-07-22 07:14:24 UTC                     2.0
# ...         ...         ...                      ...                     ...
# 1074144     NaN         NaN                      NaN                     NaN
# 1074145     NaN         NaN                      NaN                     NaN
# 1074146     NaN         NaN                      NaN                     NaN
# 1074147     NaN         NaN                      NaN                     NaN
# 1074148     NaN         NaN                      NaN                     NaN
#
# ...

# %%
db
# Out:
# Amount                      25574
# PayeeRefID                  25574
# CreatedDate                 25574
# TransactionStatusRefID      25574
# CustID                          0
# DistributorRefID            25574
# TicketCreatedDateTime     1048575
# dtype: int64

# %%
df_index = pd.merge(df2, df1, right_index=True, left_index = True)

df_index
# Out:
#       TicketCreatedDateTime  CustID_x  Amount  PayeeRefID  \
# 0          12-11-2018 15:27         3     2.0       12104
# 1          12-11-2018 15:29         3     2.0       12104
# 2          19-09-2018 12:23         4     2.0    24979501
# 3          30-08-2018 12:18         4     2.0       12104
# 4          14-09-2018 12:55         4   100.0    15957319
# ...                     ...       ...     ...         ...
# 25569      31-12-2018 11:31      4590  3000.0      896114
# 25570      28-12-2018 10:47      4595  3000.0    15904421
# 25571      20-12-2018 08:33      4595  3000.0      192445
# 25572      29-12-2018 13:11      4595  3000.0     2433039
# 25573      29-12-2018 17:54      4595  3000.0    17197133
#
#                    CreatedDate  TransactionStatusRefID  CustID_y  \
# 0      2018-10-14 13:52:31 UTC                       2         1
# 1      2018-08-11 16:55:33 UTC                       2         1
# 2      2019-02-21 16:33:03 UTC                       2         1
# ...

# %%
df_index.isnull().sum()
# Out:
# Amount                    0
# PayeeRefID                0
# CreatedDate               0
# TransactionStatusRefID    0
# CustID_x                  0
# DistributorRefID          0
# TicketCreatedDateTime     0
# CustID_y                  0
# dtype: int64

# %%
df_index.shape
# Out:
# (25574, 8)

# %%
df1.shape
# Out:
# (1048575, 6)

# %%
df2.shape
# Out:
# (25574, 2)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-e45c5eaf3634> in <module>
#       1 df_merge_asof = pd.merge_asof(df1, df2,
# ----> 2               on='CustID')
#       3
#       4 df_merge_asof
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge_asof(left, right, on, left_on, right_on, left_index, right_index, by, left_by, right_by, suffixes, tolerance, allow_exact_matches, direction)
#     539         direction=direction,
#     540     )
# --> 541     return op.get_result()
#     542
#     543
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in get_result(self)
#    1459
#    1460     def get_result(self):
# -> 1461         join_index, left_indexer, right_indexer = self._get_join_info()
#    1462
#    1463         # this is a bit kludgy
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_join_info(self)
# ...
